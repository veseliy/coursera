# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn.datasets import load_boston
boston = load_boston()

# %%
boston.keys()
# Out:
# ['data', 'feature_names', 'DESCR', 'target']

# %%
X=boston.data
y=boston.target

# %%
pylab.plot(boston.target)

# %%
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.25, random_state=42)

# %%
def gbm_predict(X):
    return [sum([coeff * algo.predict([x])[0] for algo, coeff in zip(base_algorithms_list, coefficients_list)]) for x in X]

# %%
dtreeReg=DecisionTreeRegressor(max_depth=5,random_state=42)

# %%
base_algorithms_list=[]
for i in range(5):
    dtreeReg=DecisionTreeRegressor(max_depth=5,random_state=42)
    base_algorithms_list.append(dtreeReg.fit(X_train,y_train))

# %%
len(base_algorithms_list[0].predict(X_test)),len(y_test)
# Out:
# (127, 127)

# %%
-2*(base_algorithms_list[0].predict(X_test)-y_test)
# Out:
# array([  5.16814159e+00,   4.70000000e+00,  -7.65238095e+00,
#         -1.77037037e+00,  -2.65238095e+00,  -2.03185841e+00,
#          7.47619048e-01,  -1.20833333e+00,  -2.83185841e+00,
#         -8.43185841e+00,   8.14761905e+00,   2.94761905e+00,
#         -4.20000000e+00,   3.68141593e-01,  -5.03185841e+00,
#          1.07000000e+01,   2.74761905e+00,   2.20000000e+00,
#          1.11636364e+01,   2.62500000e-01,   3.02962963e+00,
#          1.08296296e+01,  -3.80833333e+00,  -7.17037037e+00,
#         -6.45238095e+00,  -3.37500000e-01,  -1.43185841e+00,
#          1.86250000e+00,   8.54761905e+00,  -5.43185841e+00,
#          1.13476190e+01,   2.29629630e-01,   9.20000000e+00,
#         -4.31858407e-01,   8.99166667e+00,   3.94761905e+00,
#          3.11176471e+00,  -3.03185841e+00,   4.20000000e+00,
#         -5.70370370e-01,   2.00000000e-01,   4.42962963e+00,
#          1.11636364e+01,  -7.23185841e+00,   3.16814159e+00,
# ...
